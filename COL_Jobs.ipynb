# %% [markdown]
# # FILE 3 of 4

# %% [markdown]
# # Collecting Cost of Living Data

# %%
#import dependencies
import pandas as pd

# %%
#Data Scource URL
url = 'https://www.numbeo.com/cost-of-living/rankings.jsp'

# %% [markdown]
# # Collect list of tables from source url

# %%
#Created a Table into Data Scource
tables = pd.read_html(url)
tables
# Out:
# [    0                                                  1
#  0 NaN  whenDocReady(function() {  jQuery('#city_selec...,
#       Rank                       City  Cost of Living Index  Rent Index  \
#  0     NaN        Zurich, Switzerland                131.49       64.37
#  1     NaN        Lugano, Switzerland                130.75       40.20
#  2     NaN         Basel, Switzerland                130.65       46.61
#  3     NaN        Geneva, Switzerland                126.08       66.56
#  4     NaN      Lausanne, Switzerland                125.03       51.99
#  ..    ...                        ...                   ...         ...
#  509   NaN         Bhubaneswar, India                 22.11        3.66
#  510   NaN           Lahore, Pakistan                 21.96        4.50
#  511   NaN          Karachi, Pakistan                 21.52        4.21
#  512   NaN       Visakhapatnam, India                 21.30        3.80
#  513   NaN  Thiruvananthapuram, India                 19.85        4.17
#
#       Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
#  0                             98.80           131.23                  120.39
#  1                             86.66           134.80                  115.19
#  2                             89.72           126.05                  131.92
#  3                             97.10           123.84                  119.47
#  4                             89.46           125.56                  118.13
#  ..                              ...              ...                     ...
#  509                           13.13            23.78                   11.86
#  510                           13.46            18.91                   16.02
#  511                           13.09            18.85                   16.73
#  512                           12.78            22.62                   13.06
#  513                           12.21            21.09                   10.74
#
#       Local Purchasing Power Index
#  0                          121.12
#  1                          101.15
#  2                          109.90
#  3                          108.09
#  4                          110.86
#  ..                            ...
#  509                         59.20
#  510                         27.48
#  511                         27.94
#  512                         49.37
#  513                         59.95
#
#  [514 rows x 8 columns]]

# %%
type(tables)
# Out:
# list

# %% [markdown]
# # Identify and clean target table

# %%
#Column Names for Data Frame
df = pd.DataFrame(tables[1])
df.columns = ['Rank', 'City', 'COL Index', 'Rent Index', 'COL Plus Rent Index', 
              'Groceries Index', 'Restaurant Price Index', 'Local Purchasing Power Index']
df.head()
# Out:
#    Rank                   City  COL Index  Rent Index  COL Plus Rent Index  \
# 0   NaN    Zurich, Switzerland     131.49       64.37                98.80
# 1   NaN    Lugano, Switzerland     130.75       40.20                86.66
# 2   NaN     Basel, Switzerland     130.65       46.61                89.72
# 3   NaN    Geneva, Switzerland     126.08       66.56                97.10
# 4   NaN  Lausanne, Switzerland     125.03       51.99                89.46
#
#    Groceries Index  Restaurant Price Index  Local Purchasing Power Index
# 0           131.23                  120.39                        121.12
# 1           134.80                  115.19                        101.15
# 2           126.05                  131.92                        109.90
# 3           123.84                  119.47                        108.09
# 4           125.56                  118.13                        110.86

# %% [markdown]
# ## Separate city and state/country

# %%
#Separating the the city name from state/country
city_df = df['City'].apply(lambda x: pd.Series(x.split(',')))
city_df.head()
# Out:
#           0             1    2
# 0    Zurich   Switzerland  NaN
# 1    Lugano   Switzerland  NaN
# 2     Basel   Switzerland  NaN
# 3    Geneva   Switzerland  NaN
# 4  Lausanne   Switzerland  NaN

# %%
#Added the Split_City column into the data frame
df["split_city"] = city_df[0]
df.head()
# Out:
#    Rank                   City  COL Index  Rent Index  COL Plus Rent Index  \
# 0   NaN    Zurich, Switzerland     131.49       64.37                98.80
# 1   NaN    Lugano, Switzerland     130.75       40.20                86.66
# 2   NaN     Basel, Switzerland     130.65       46.61                89.72
# 3   NaN    Geneva, Switzerland     126.08       66.56                97.10
# 4   NaN  Lausanne, Switzerland     125.03       51.99                89.46
#
#    Groceries Index  Restaurant Price Index  Local Purchasing Power Index  \
# 0           131.23                  120.39                        121.12
# 1           134.80                  115.19                        101.15
# 2           126.05                  131.92                        109.90
# 3           123.84                  119.47                        108.09
# 4           125.56                  118.13                        110.86
#
#   split_city
# 0     Zurich
# 1     Lugano
# 2      Basel
# 3     Geneva
# 4   Lausanne

# %% [markdown]
# ## Remove unwanted columns

# %%
#Removed the Rank and COL Plus Rent Index column from the data frame
clean_df = df.drop(['Rank', 'COL Plus Rent Index'], axis=1)

# %%
clean_df
# Out:
#                           City  COL Index  Rent Index  Groceries Index  \
# 0          Zurich, Switzerland     131.49       64.37           131.23
# 1          Lugano, Switzerland     130.75       40.20           134.80
# 2           Basel, Switzerland     130.65       46.61           126.05
# 3          Geneva, Switzerland     126.08       66.56           123.84
# 4        Lausanne, Switzerland     125.03       51.99           125.56
# ..                         ...        ...         ...              ...
# 509         Bhubaneswar, India      22.11        3.66            23.78
# 510           Lahore, Pakistan      21.96        4.50            18.91
# 511          Karachi, Pakistan      21.52        4.21            18.85
# 512       Visakhapatnam, India      21.30        3.80            22.62
# 513  Thiruvananthapuram, India      19.85        4.17            21.09
#
#      Restaurant Price Index  Local Purchasing Power Index          split_city
# 0                    120.39                        121.12              Zurich
# 1                    115.19                        101.15              Lugano
# 2                    131.92                        109.90               Basel
# 3                    119.47                        108.09              Geneva
# 4                    118.13                        110.86            Lausanne
# ..                      ...                           ...                 ...
# 509                   11.86                         59.20         Bhubaneswar
# 510                   16.02                         27.48              Lahore
# 511                   16.73                         27.94             Karachi
# 512                   13.06                         49.37       Visakhapatnam
# 513                   10.74                         59.95  Thiruvananthapuram
#
# [514 rows x 7 columns]

# %% [markdown]
# ## Store data as list of dictionaries

# %%
#created the data diction from the data frame
COL_dict = clean_df.to_dict("records")

# %%
COL_dict
# Out:
# [{'City': 'Zurich, Switzerland',
#   'COL Index': 131.49,
#   'Rent Index': 64.37,
#   'Groceries Index': 131.23,
#   'Restaurant Price Index': 120.39,
#   'Local Purchasing Power Index': 121.12,
#   'split_city': 'Zurich'},
#  {'City': 'Lugano, Switzerland',
#   'COL Index': 130.75,
#   'Rent Index': 40.2,
#   'Groceries Index': 134.8,
#   'Restaurant Price Index': 115.19,
#   'Local Purchasing Power Index': 101.15,
#   'split_city': 'Lugano'},
#  {'City': 'Basel, Switzerland',
#   'COL Index': 130.65,
#   'Rent Index': 46.61,
#   'Groceries Index': 126.05,
#   'Restaurant Price Index': 131.92,
#   'Local Purchasing Power Index': 109.9,
#   'split_city': 'Basel'},
#  {'City': 'Geneva, Switzerland',
#   'COL Index': 126.08,
#   'Rent Index': 66.56,
#   'Groceries Index': 123.84,
#   'Restaurant Price Index': 119.47,
#   'Local Purchasing Power Index': 108.09,
#   'split_city': 'Geneva'},
#  {'City': 'Lausanne, Switzerland',
#   'COL Index': 125.03,
#   'Rent Index': 51.99,
#   'Groceries Index': 125.56,
#   'Restaurant Price Index': 118.13,
#   'Local Purchasing Power Index': 110.86,
#   'split_city': 'Lausanne'},
#  {'City': 'Bern, Switzerland',
#   'COL Index': 116.53,
#   'Rent Index': 41.6,
#   'Groceries Index': 106.32,
#   'Restaurant Price Index': 110.46,
#   'Local Purchasing Power Index': 125.72,
#   'split_city': 'Bern'},
#  {'City': 'New York, NY, United States',
#   'COL Index': 100.0,
#   'Rent Index': 100.0,
#   'Groceries Index': 100.0,
#   'Restaurant Price Index': 100.0,
#   'Local Purchasing Power Index': 100.0,
#   'split_city': 'New York'},
#  {'City': 'Trondheim, Norway',
#   'COL Index': 98.23,
#   'Rent Index': 34.32,
#   'Groceries Index': 93.13,
#   'Restaurant Price Index': 94.83,
#   'Local Purchasing Power Index': 83.32,
#   'split_city': 'Trondheim'},
#  {'City': 'Stavanger, Norway',
#   'COL Index': 97.91,
#   'Rent Index': 32.75,
#   'Groceries Index': 90.42,
#   'Restaurant Price Index': 99.35,
#   'Local Purchasing Power Index': 83.99,
#   'split_city': 'Stavanger'},
#  {'City': 'Oslo, Norway',
#   'COL Index': 95.78,
#   'Rent Index': 40.23,
#   'Groceries Index': 88.4,
#   'Restaurant Price Index': 96.2,
#   'Local Purchasing Power Index': 86.05,
#   'split_city': 'Oslo'},
#  {'City': 'Bergen, Norway',
#   'COL Index': 94.78,
#   'Rent Index': 31.59,
#   'Groceries Index': 85.87,
#   'Restaurant Price Index': 96.17,
#   'Local Purchasing Power Index': 93.49,
#   'split_city': 'Bergen'},
#  {'City': 'San Francisco, CA, United States',
#   'COL Index': 92.13,
#   'Rent Index': 109.76,
#   'Groceries Index': 89.79,
#   'Restaurant Price Index': 88.26,
#   'Local Purchasing Power Index': 139.0,
#   'split_city': 'San Francisco'},
#  {'City': 'Reykjavik, Iceland',
#   'COL Index': 91.81,
#   'Rent Index': 42.83,
#   'Groceries Index': 81.91,
#   'Restaurant Price Index': 102.07,
#   'Local Purchasing Power Index': 74.76,
#   'split_city': 'Reykjavik'},
#  {'City': 'Tel Aviv-Yafo, Israel',
#   'COL Index': 91.4,
#   'Rent Index': 43.17,
#   'Groceries Index': 80.53,
#   'Restaurant Price Index': 92.53,
#   'Local Purchasing Power Index': 67.85,
#   'split_city': 'Tel Aviv-Yafo'},
#  {'City': 'Copenhagen, Denmark',
#   'COL Index': 90.85,
#   'Rent Index': 46.33,
#   'Groceries Index': 68.37,
#   'Restaurant Price Index': 102.96,
#   'Local Purchasing Power Index': 91.35,
#   'split_city': 'Copenhagen'},
#  {'City': 'Anchorage, AK, United States',
#   'COL Index': 90.83,
#   'Rent Index': 36.51,
#   'Groceries Index': 89.86,
#   'Restaurant Price Index': 75.91,
#   'Local Purchasing Power Index': 119.91,
#   'split_city': 'Anchorage'},
#  {'City': 'Tokyo, Japan',
#   'COL Index': 89.69,
#   'Rent Index': 38.36,
#   'Groceries Index': 90.93,
#   'Restaurant Price Index': 49.17,
#   'Local Purchasing Power Index': 75.09,
#   'split_city': 'Tokyo'},
#  {'City': 'Nassau, Bahamas',
#   'COL Index': 89.57,
#   'Rent Index': 38.57,
#   'Groceries Index': 76.56,
#   'Restaurant Price Index': 83.5,
#   'Local Purchasing Power Index': 45.96,
#   'split_city': 'Nassau'},
#  {'City': 'Paris, France',
#   'COL Index': 88.83,
#   'Rent Index': 45.38,
#   'Groceries Index': 86.8,
#   'Restaurant Price Index': 76.97,
#   'Local Purchasing Power Index': 69.54,
#   'split_city': 'Paris'},
#  {'City': 'Oakland, CA, United States',
#   'COL Index': 88.68,
#   'Rent Index': 79.83,
#   'Groceries Index': 94.92,
#   'Restaurant Price Index': 72.03,
#   'Local Purchasing Power Index': 97.98,
#   'split_city': 'Oakland'},
#  {'City': 'Boston, MA, United States',
#   'COL Index': 88.61,
#   'Rent Index': 75.13,
#   'Groceries Index': 89.28,
#   'Restaurant Price Index': 84.34,
#   'Local Purchasing Power Index': 107.59,
#   'split_city': 'Boston'},
#  {'City': 'Arhus, Denmark',
#   'COL Index': 88.04,
#   'Rent Index': 31.88,
#   'Groceries Index': 69.65,
#   'Restaurant Price Index': 92.73,
#   'Local Purchasing Power Index': 91.01,
#   'split_city': 'Arhus'},
#  {'City': 'Seattle, WA, United States',
#   'COL Index': 87.99,
#   'Rent Index': 64.0,
#   'Groceries Index': 80.83,
#   'Restaurant Price Index': 86.82,
#   'Local Purchasing Power Index': 133.18,
#   'split_city': 'Seattle'},
#  {'City': 'Aalborg, Denmark',
#   'COL Index': 87.58,
#   'Rent Index': 24.19,
#   'Groceries Index': 75.6,
#   'Restaurant Price Index': 95.27,
#   'Local Purchasing Power Index': 105.92,
#   'split_city': 'Aalborg'},
#  {'City': 'Honolulu, HI, United States',
#   'COL Index': 87.05,
#   'Rent Index': 61.82,
#   'Groceries Index': 87.3,
#   'Restaurant Price Index': 77.49,
#   'Local Purchasing Power Index': 76.47,
#   'split_city': 'Honolulu'},
#  {'City': 'Osaka, Japan',
#   'COL Index': 87.02,
#   'Rent Index': 23.28,
#   'Groceries Index': 89.91,
#   'Restaurant Price Index': 47.72,
#   'Local Purchasing Power Index': 79.93,
#   'split_city': 'Osaka'},
#  {'City': 'Washington, DC, United States',
#   'COL Index': 84.69,
#   'Rent Index': 75.05,
#   'Groceries Index': 80.31,
#   'Restaurant Price Index': 81.33,
#   'Local Purchasing Power Index': 117.21,
#   'split_city': 'Washington'},
#  {'City': 'Miami, FL, United States',
#   'COL Index': 83.61,
#   'Rent Index': 55.99,
#   'Groceries Index': 82.92,
#   'Restaurant Price Index': 77.7,
#   'Local Purchasing Power Index': 91.09,
#   'split_city': 'Miami'},
#  {'City': 'Luxembourg, Luxembourg',
#   'COL Index': 83.56,
#   'Rent Index': 56.37,
#   'Groceries Index': 73.25,
#   'Restaurant Price Index': 87.81,
#   'Local Purchasing Power Index': 106.44,
#   'split_city': 'Luxembourg'},
#  {'City': 'Dubrovnik, Croatia',
#   'COL Index': 83.43,
#   'Rent Index': 25.68,
#   'Groceries Index': 81.72,
#   'Restaurant Price Index': 78.67,
#   'Local Purchasing Power Index': 31.94,
#   'split_city': 'Dubrovnik'},
#  {'City': 'Charleston, SC, United States',
#   'COL Index': 83.21,
#   'Rent Index': 48.43,
#   'Groceries Index': 87.18,
#   'Restaurant Price Index': 72.91,
#   'Local Purchasing Power Index': 99.2,
#   'split_city': 'Charleston'},
#  {'City': 'Minneapolis, MN, United States',
#   'COL Index': 83.18,
#   'Rent Index': 42.55,
#   'Groceries Index': 79.81,
#   'Restaurant Price Index': 77.37,
#   'Local Purchasing Power Index': 116.05,
#   'split_city': 'Minneapolis'},
#  {'City': 'Amsterdam, Netherlands',
#   'COL Index': 82.86,
#   'Rent Index': 55.21,
#   'Groceries Index': 63.25,
#   'Restaurant Price Index': 86.93,
#   'Local Purchasing Power Index': 82.74,
#   'split_city': 'Amsterdam'},
#  {'City': 'Sydney, Australia',
#   'COL Index': 82.73,
#   'Rent Index': 54.16,
#   'Groceries Index': 75.43,
#   'Restaurant Price Index': 70.73,
#   'Local Purchasing Power Index': 94.59,
#   'split_city': 'Sydney'},
#  {'City': 'Chicago, IL, United States',
#   'COL Index': 82.71,
#   'Rent Index': 55.16,
#   'Groceries Index': 80.96,
#   'Restaurant Price Index': 75.44,
#   'Local Purchasing Power Index': 109.82,
#   'split_city': 'Chicago'},
#  {'City': 'Seoul, South Korea',
#   'COL Index': 81.59,
#   'Rent Index': 29.64,
#   'Groceries Index': 99.4,
#   'Restaurant Price Index': 45.51,
#   'Local Purchasing Power Index': 76.53,
#   'split_city': 'Seoul'},
#  {'City': 'Dublin, Ireland',
#   'COL Index': 81.39,
#   'Rent Index': 60.18,
#   'Groceries Index': 65.26,
#   'Restaurant Price Index': 78.5,
#   'Local Purchasing Power Index': 68.13,
#   'split_city': 'Dublin'},
#  {'City': 'Fort Lauderdale, FL, United States',
#   'COL Index': 81.22,
#   'Rent Index': 53.32,
#   'Groceries Index': 90.86,
#   'Restaurant Price Index': 68.86,
#   'Local Purchasing Power Index': 99.37,
#   'split_city': 'Fort Lauderdale'},
#  {'City': 'Portland, OR, United States',
#   'COL Index': 81.19,
#   'Rent Index': 46.99,
#   'Groceries Index': 81.78,
#   'Restaurant Price Index': 69.78,
#   'Local Purchasing Power Index': 103.41,
#   'split_city': 'Portland'},
#  {'City': 'Singapore, Singapore',
#   'COL Index': 81.13,
#   'Rent Index': 61.27,
#   'Groceries Index': 69.2,
#   'Restaurant Price Index': 58.0,
#   'Local Purchasing Power Index': 82.61,
#   'split_city': 'Singapore'},
#  {'City': 'Milan, Italy',
#   'COL Index': 80.37,
#   'Rent Index': 42.7,
#   'Groceries Index': 68.87,
#   'Restaurant Price Index': 78.51,
#   'Local Purchasing Power Index': 52.35,
#   'split_city': 'Milan'},
#  {'City': 'Haifa, Israel',
#   'COL Index': 80.32,
#   'Rent Index': 20.63,
#   'Groceries Index': 63.88,
#   'Restaurant Price Index': 84.36,
#   'Local Purchasing Power Index': 79.07,
#   'split_city': 'Haifa'},
#  {'City': 'Jerusalem, Israel',
#   'COL Index': 80.2,
#   'Rent Index': 31.8,
#   'Groceries Index': 63.38,
#   'Restaurant Price Index': 87.85,
#   'Local Purchasing Power Index': 68.97,
#   'split_city': 'Jerusalem'},
#  {'City': 'Utrecht, Netherlands',
#   'COL Index': 80.04,
#   'Rent Index': 40.78,
#   'Groceries Index': 61.14,
#   'Restaurant Price Index': 84.27,
#   'Local Purchasing Power Index': 77.35,
#   'split_city': 'Utrecht'},
#  {'City': 'Irvine, CA, United States',
#   'COL Index': 79.94,
#   'Rent Index': 65.43,
#   'Groceries Index': 73.02,
#   'Restaurant Price Index': 78.68,
#   'Local Purchasing Power Index': 137.4,
#   'split_city': 'Irvine'},
#  {'City': 'Los Angeles, CA, United States',
#   'COL Index': 79.82,
#   'Rent Index': 70.01,
#   'Groceries Index': 77.95,
#   'Restaurant Price Index': 79.47,
#   'Local Purchasing Power Index': 106.0,
#   'split_city': 'Los Angeles'},
#  {'City': 'Galway, Ireland',
#   'COL Index': 79.56,
#   'Rent Index': 36.19,
#   'Groceries Index': 65.01,
#   'Restaurant Price Index': 76.22,
#   'Local Purchasing Power Index': 73.94,
#   'split_city': 'Galway'},
#  {'City': 'Philadelphia, PA, United States',
#   'COL Index': 79.19,
#   'Rent Index': 46.45,
#   'Groceries Index': 77.98,
#   'Restaurant Price Index': 67.94,
#   'Local Purchasing Power Index': 87.68,
#   'split_city': 'Philadelphia'},
#  {'City': 'Pittsburgh, PA, United States',
#   'COL Index': 79.02,
#   'Rent Index': 35.02,
#   'Groceries Index': 80.58,
#   'Restaurant Price Index': 63.79,
#   'Local Purchasing Power Index': 108.97,
#   'split_city': 'Pittsburgh'},
#  {'City': 'London, United Kingdom',
#   'COL Index': 78.83,
#   'Rent Index': 65.17,
#   'Groceries Index': 56.22,
#   'Restaurant Price Index': 82.38,
#   'Local Purchasing Power Index': 84.56,
#   'split_city': 'London'},
#  {'City': 'Uppsala, Sweden',
#   'COL Index': 78.64,
#   'Rent Index': 25.98,
#   'Groceries Index': 71.9,
#   'Restaurant Price Index': 76.1,
#   'Local Purchasing Power Index': 78.64,
#   'split_city': 'Uppsala'},
#  {'City': 'Cleveland, OH, United States',
#   'COL Index': 78.62,
#   'Rent Index': 37.7,
#   'Groceries Index': 82.07,
#   'Restaurant Price Index': 66.89,
#   'Local Purchasing Power Index': 90.67,
#   'split_city': 'Cleveland'},
#  {'City': 'Milwaukee, WI, United States',
#   'COL Index': 78.6,
#   'Rent Index': 33.97,
#   'Groceries Index': 79.61,
#   'Restaurant Price Index': 69.62,
#   'Local Purchasing Power Index': 88.12,
#   'split_city': 'Milwaukee'},
#  {'City': 'Stockholm, Sweden',
#   'COL Index': 78.59,
#   'Rent Index': 38.44,
#   'Groceries Index': 67.97,
#   'Restaurant Price Index': 79.02,
#   'Local Purchasing Power Index': 81.37,
#   'split_city': 'Stockholm'},
#  {'City': 'Sacramento, CA, United States',
#   'COL Index': 78.57,
#   'Rent Index': 45.12,
#   'Groceries Index': 76.97,
#   'Restaurant Price Index': 69.03,
#   'Local Purchasing Power Index': 109.38,
#   'split_city': 'Sacramento'},
#  {'City': 'Odense, Denmark',
#   'COL Index': 78.55,
#   'Rent Index': 25.26,
#   'Groceries Index': 59.73,
#   'Restaurant Price Index': 92.73,
#   'Local Purchasing Power Index': 96.18,
#   'split_city': 'Odense'},
#  {'City': 'Cork, Ireland',
#   'COL Index': 78.39,
#   'Rent Index': 40.23,
#   'Groceries Index': 64.08,
#   'Restaurant Price Index': 76.87,
#   'Local Purchasing Power Index': 75.05,
#   'split_city': 'Cork'},
#  {'City': 'San Diego, CA, United States',
#   'COL Index': 78.3,
#   'Rent Index': 65.59,
#   'Groceries Index': 74.35,
#   'Restaurant Price Index': 77.62,
#   'Local Purchasing Power Index': 121.07,
#   'split_city': 'San Diego'},
#  {'City': 'Nice, France',
#   'COL Index': 78.08,
#   'Rent Index': 32.47,
#   'Groceries Index': 72.99,
#   'Restaurant Price Index': 75.1,
#   'Local Purchasing Power Index': 66.03,
#   'split_city': 'Nice'},
#  {'City': 'Hong Kong, Hong Kong',
#   'COL Index': 77.9,
#   'Rent Index': 75.26,
#   'Groceries Index': 77.47,
#   'Restaurant Price Index': 54.7,
#   'Local Purchasing Power Index': 67.02,
#   'split_city': 'Hong Kong'},
#  {'City': 'Newcastle, Australia',
#   'COL Index': 77.9,
#   'Rent Index': 37.3,
#   'Groceries Index': 70.24,
#   'Restaurant Price Index': 77.47,
#   'Local Purchasing Power Index': 115.96,
#   'split_city': 'Newcastle'},
#  {'City': 'Asheville, NC, United States',
#   'COL Index': 77.61,
#   'Rent Index': 39.87,
#   'Groceries Index': 80.25,
#   'Restaurant Price Index': 72.72,
#   'Local Purchasing Power Index': 102.44,
#   'split_city': 'Asheville'},
#  {'City': 'San Jose, CA, United States',
#   'COL Index': 77.55,
#   'Rent Index': 81.32,
#   'Groceries Index': 69.57,
#   'Restaurant Price Index': 82.46,
#   'Local Purchasing Power Index': 143.11,
#   'split_city': 'San Jose'},
#  {'City': 'Eindhoven, Netherlands',
#   'COL Index': 77.2,
#   'Rent Index': 34.57,
#   'Groceries Index': 61.09,
#   'Restaurant Price Index': 76.9,
#   'Local Purchasing Power Index': 92.14,
#   'split_city': 'Eindhoven'},
#  {'City': 'New Orleans, LA, United States',
#   'COL Index': 77.0,
#   'Rent Index': 40.11,
#   'Groceries Index': 75.77,
#   'Restaurant Price Index': 72.2,
#   'Local Purchasing Power Index': 87.22,
#   'split_city': 'New Orleans'},
#  {'City': 'Brighton, United Kingdom',
#   'COL Index': 76.94,
#   'Rent Index': 39.6,
#   'Groceries Index': 61.44,
#   'Restaurant Price Index': 80.59,
#   'Local Purchasing Power Index': 72.1,
#   'split_city': 'Brighton'},
#  {'City': 'Auckland, New Zealand',
#   'COL Index': 76.91,
#   'Rent Index': 39.35,
#   'Groceries Index': 71.03,
#   'Restaurant Price Index': 66.46,
#   'Local Purchasing Power Index': 83.54,
#   'split_city': 'Auckland'},
#  {'City': 'Birmingham, AL, United States',
#   'COL Index': 76.72,
#   'Rent Index': 29.18,
#   'Groceries Index': 78.72,
#   'Restaurant Price Index': 61.02,
#   'Local Purchasing Power Index': 88.81,
#   'split_city': 'Birmingham'},
#  {'City': 'Tampa, FL, United States',
#   'COL Index': 76.72,
#   'Rent Index': 40.21,
#   'Groceries Index': 82.97,
#   'Restaurant Price Index': 63.7,
#   'Local Purchasing Power Index': 117.29,
#   'split_city': 'Tampa'},
#  {'City': 'Grenoble, France',
#   'COL Index': 76.52,
#   'Rent Index': 21.1,
#   'Groceries Index': 74.02,
#   'Restaurant Price Index': 68.87,
#   'Local Purchasing Power Index': 76.42,
#   'split_city': 'Grenoble'},
#  {'City': 'Perth, Australia',
#   'COL Index': 76.39,
#   'Rent Index': 28.36,
#   'Groceries Index': 67.3,
#   'Restaurant Price Index': 72.75,
#   'Local Purchasing Power Index': 102.49,
#   'split_city': 'Perth'},
#  {'City': 'Haarlem, Netherlands',
#   'COL Index': 76.35,
#   'Rent Index': 47.46,
#   'Groceries Index': 57.16,
#   'Restaurant Price Index': 75.61,
#   'Local Purchasing Power Index': 85.13,
#   'split_city': 'Haarlem'},
#  {'City': 'Valletta, Malta',
#   'COL Index': 76.3,
#   'Rent Index': 41.0,
#   'Groceries Index': 63.42,
#   'Restaurant Price Index': 80.29,
#   'Local Purchasing Power Index': 36.99,
#   'split_city': 'Valletta'},
#  {'City': 'Atlanta, GA, United States',
#   'COL Index': 76.11,
#   'Rent Index': 46.88,
#   'Groceries Index': 75.86,
#   'Restaurant Price Index': 64.01,
#   'Local Purchasing Power Index': 131.11,
#   'split_city': 'Atlanta'},
#  {'City': 'Linz, Austria',
#   'COL Index': 76.03,
#   'Rent Index': 25.59,
#   'Groceries Index': 67.48,
#   'Restaurant Price Index': 75.21,
#   'Local Purchasing Power Index': 75.63,
#   'split_city': 'Linz'},
#  {'City': 'Brisbane, Australia',
#   'COL Index': 75.78,
#   'Rent Index': 33.43,
#   'Groceries Index': 70.6,
#   'Restaurant Price Index': 71.89,
#   'Local Purchasing Power Index': 105.31,
#   'split_city': 'Brisbane'},
#  {'City': 'Charlotte, NC, United States',
#   'COL Index': 75.7,
#   'Rent Index': 42.2,
#   'Groceries Index': 68.67,
#   'Restaurant Price Index': 70.5,
#   'Local Purchasing Power Index': 126.48,
#   'split_city': 'Charlotte'},
#  {'City': 'Tampere, Finland',
#   'COL Index': 75.66,
#   'Rent Index': 24.25,
#   'Groceries Index': 66.48,
#   'Restaurant Price Index': 75.46,
#   'Local Purchasing Power Index': 88.19,
#   'split_city': 'Tampere'},
#  {'City': 'Munich, Germany',
#   'COL Index': 75.56,
#   'Rent Index': 43.87,
#   'Groceries Index': 58.16,
#   'Restaurant Price Index': 74.28,
#   'Local Purchasing Power Index': 91.09,
#   'split_city': 'Munich'},
#  {'City': 'Canberra, Australia',
#   'COL Index': 75.51,
#   'Rent Index': 38.5,
#   'Groceries Index': 73.81,
#   'Restaurant Price Index': 69.56,
#   'Local Purchasing Power Index': 107.36,
#   'split_city': 'Canberra'},
#  {'City': 'Groningen, Netherlands',
#   'COL Index': 75.48,
#   'Rent Index': 26.36,
#   'Groceries Index': 58.79,
#   'Restaurant Price Index': 73.67,
#   'Local Purchasing Power Index': 82.12,
#   'split_city': 'Groningen'},
#  {'City': 'Lyon, France',
#   'COL Index': 75.47,
#   'Rent Index': 25.3,
#   'Groceries Index': 68.68,
#   'Restaurant Price Index': 66.99,
#   'Local Purchasing Power Index': 81.1,
#   'split_city': 'Lyon'},
#  {'City': 'Helsinki, Finland',
#   'COL Index': 75.39,
#   'Rent Index': 35.09,
#   'Groceries Index': 63.66,
#   'Restaurant Price Index': 81.84,
#   'Local Purchasing Power Index': 89.82,
#   'split_city': 'Helsinki'},
#  {'City': 'Marseille, France',
#   'COL Index': 75.22,
#   'Rent Index': 23.47,
#   'Groceries Index': 72.3,
#   'Restaurant Price Index': 67.71,
#   'Local Purchasing Power Index': 62.79,
#   'split_city': 'Marseille'},
#  {'City': 'Baltimore, MD, United States',
#   'COL Index': 75.04,
#   'Rent Index': 42.35,
#   'Groceries Index': 71.1,
#   'Restaurant Price Index': 72.33,
#   'Local Purchasing Power Index': 107.83,
#   'split_city': 'Baltimore'},
#  {'City': 'Gold Coast, Australia',
#   'COL Index': 75.0,
#   'Rent Index': 36.09,
#   'Groceries Index': 68.58,
#   'Restaurant Price Index': 76.69,
#   'Local Purchasing Power Index': 109.38,
#   'split_city': 'Gold Coast'},
#  {'City': 'Graz, Austria',
#   'COL Index': 74.97,
#   'Rent Index': 20.34,
#   'Groceries Index': 69.1,
#   'Restaurant Price Index': 59.87,
#   'Local Purchasing Power Index': 78.02,
#   'split_city': 'Graz'},
#  {'City': 'Christchurch, New Zealand',
#   'COL Index': 74.87,
#   'Rent Index': 28.71,
#   'Groceries Index': 69.41,
#   'Restaurant Price Index': 70.9,
#   'Local Purchasing Power Index': 87.81,
#   'split_city': 'Christchurch'},
#  {'City': 'Maastricht, Netherlands',
#   'COL Index': 74.68,
#   'Rent Index': 33.56,
#   'Groceries Index': 57.47,
#   'Restaurant Price Index': 78.63,
#   'Local Purchasing Power Index': 79.27,
#   'split_city': 'Maastricht'},
#  {'City': 'Leiden, Netherlands',
#   'COL Index': 74.49,
#   'Rent Index': 32.26,
#   'Groceries Index': 57.09,
#   'Restaurant Price Index': 72.89,
#   'Local Purchasing Power Index': 83.99,
#   'split_city': 'Leiden'},
#  {'City': 'Ann Arbor, MI, United States',
#   'COL Index': 74.43,
#   'Rent Index': 49.47,
#   'Groceries Index': 73.55,
#   'Restaurant Price Index': 63.15,
#   'Local Purchasing Power Index': 116.23,
#   'split_city': 'Ann Arbor'},
#  {'City': 'Nijmegen, Netherlands',
#   'COL Index': 74.38,
#   'Rent Index': 30.89,
#   'Groceries Index': 57.59,
#   'Restaurant Price Index': 74.95,
#   'Local Purchasing Power Index': 104.87,
#   'split_city': 'Nijmegen'},
#  {'City': 'Parma, Italy',
#   'COL Index': 74.36,
#   'Rent Index': 20.55,
#   'Groceries Index': 56.33,
#   'Restaurant Price Index': 83.38,
#   'Local Purchasing Power Index': 59.75,
#   'split_city': 'Parma'},
#  {'City': 'Toulouse, France',
#   'COL Index': 74.3,
#   'Rent Index': 21.65,
#   'Groceries Index': 70.27,
#   'Restaurant Price Index': 68.55,
#   'Local Purchasing Power Index': 89.93,
#   'split_city': 'Toulouse'},
#  {'City': 'Rochester, NY, United States',
#   'COL Index': 74.28,
#   'Rent Index': 28.53,
#   'Groceries Index': 72.72,
#   'Restaurant Price Index': 71.06,
#   'Local Purchasing Power Index': 103.52,
#   'split_city': 'Rochester'},
#  {'City': 'Denver, CO, United States',
#   'COL Index': 74.27,
#   'Rent Index': 51.15,
#   'Groceries Index': 64.86,
#   'Restaurant Price Index': 76.33,
#   'Local Purchasing Power Index': 121.05,
#   'split_city': 'Denver'},
#  {'City': 'Leuven, Belgium',
#   'COL Index': 74.0,
#   'Rent Index': 24.72,
#   'Groceries Index': 63.04,
#   'Restaurant Price Index': 75.39,
#   'Local Purchasing Power Index': 77.36,
#   'split_city': 'Leuven'},
#  {'City': 'Genoa, Italy',
#   'COL Index': 73.98,
#   'Rent Index': 18.53,
#   'Groceries Index': 66.05,
#   'Restaurant Price Index': 70.44,
#   'Local Purchasing Power Index': 57.61,
#   'split_city': 'Genoa'},
#  {'City': 'Gent, Belgium',
#   'COL Index': 73.98,
#   'Rent Index': 23.93,
#   'Groceries Index': 60.93,
#   'Restaurant Price Index': 75.06,
#   'Local Purchasing Power Index': 77.74,
#   'split_city': 'Gent'},
#  {'City': 'Melbourne, Australia',
#   'COL Index': 73.76,
#   'Rent Index': 38.69,
#   'Groceries Index': 70.91,
#   'Restaurant Price Index': 63.11,
#   'Local Purchasing Power Index': 104.83,
#   'split_city': 'Melbourne'},
#  {'City': 'Brussels, Belgium',
#   'COL Index': 73.69,
#   'Rent Index': 29.78,
#   'Groceries Index': 62.96,
#   'Restaurant Price Index': 77.32,
#   'Local Purchasing Power Index': 90.49,
#   'split_city': 'Brussels'},
#  {'City': 'Antwerp, Belgium',
#   'COL Index': 73.66,
#   'Rent Index': 24.15,
#   'Groceries Index': 59.19,
#   'Restaurant Price Index': 81.28,
#   'Local Purchasing Power Index': 82.84,
#   'split_city': 'Antwerp'},
#  {'City': 'Montpellier, France',
#   'COL Index': 73.21,
#   'Rent Index': 21.66,
#   'Groceries Index': 69.83,
#   'Restaurant Price Index': 67.56,
#   'Local Purchasing Power Index': 59.35,
#   'split_city': 'Montpellier'},
#  {'City': 'Gothenburg, Sweden',
#   'COL Index': 73.12,
#   'Rent Index': 31.02,
#   'Groceries Index': 63.84,
#   'Restaurant Price Index': 78.54,
#   'Local Purchasing Power Index': 86.06,
#   'split_city': 'Gothenburg'},
#  {'City': 'Spokane, WA, United States',
#   'COL Index': 73.12,
#   'Rent Index': 29.54,
#   'Groceries Index': 69.2,
#   'Restaurant Price Index': 72.81,
#   'Local Purchasing Power Index': 97.06,
#   'split_city': 'Spokane'},
#  {'City': 'Limerick, Ireland',
#   'COL Index': 72.98,
#   'Rent Index': 32.53,
#   'Groceries Index': 61.37,
#   'Restaurant Price Index': 64.81,
#   'Local Purchasing Power Index': 73.37,
#   'split_city': 'Limerick'},
#  {'City': 'Rome, Italy',
#   'COL Index': 72.82,
#   'Rent Index': 32.86,
#   'Groceries Index': 61.17,
#   'Restaurant Price Index': 72.27,
#   'Local Purchasing Power Index': 53.8,
#   'split_city': 'Rome'},
#  {'City': 'Columbus, OH, United States',
#   'COL Index': 72.82,
#   'Rent Index': 30.56,
#   'Groceries Index': 70.41,
#   'Restaurant Price Index': 67.67,
#   'Local Purchasing Power Index': 128.55,
#   'split_city': 'Columbus'},
#  {'City': 'Albany, NY, United States',
#   'COL Index': 72.81,
#   'Rent Index': 31.67,
#   'Groceries Index': 66.98,
#   'Restaurant Price Index': 76.42,
#   'Local Purchasing Power Index': 116.08,
#   'split_city': 'Albany'},
#  {'City': 'Sliema, Malta',
#   'COL Index': 72.69,
#   'Rent Index': 33.12,
#   'Groceries Index': 61.4,
#   'Restaurant Price Index': 78.17,
#   'Local Purchasing Power Index': 47.67,
#   'split_city': 'Sliema'},
#  {'City': 'Toronto, Canada',
#   'COL Index': 72.56,
#   'Rent Index': 47.98,
#   'Groceries Index': 66.07,
#   'Restaurant Price Index': 70.5,
#   'Local Purchasing Power Index': 81.62,
#   'split_city': 'Toronto'},
#  {'City': 'Colorado Springs, CO, United States',
#   'COL Index': 72.49,
#   'Rent Index': 34.98,
#   'Groceries Index': 74.25,
#   'Restaurant Price Index': 59.72,
#   'Local Purchasing Power Index': 110.78,
#   'split_city': 'Colorado Springs'},
#  {'City': 'Malmo, Sweden',
#   'COL Index': 72.45,
#   'Rent Index': 25.1,
#   'Groceries Index': 65.77,
#   'Restaurant Price Index': 71.99,
#   'Local Purchasing Power Index': 89.81,
#   'split_city': 'Malmo'},
#  {'City': 'Vancouver, Canada',
#   'COL Index': 72.37,
#   'Rent Index': 47.91,
#   'Groceries Index': 74.94,
#   'Restaurant Price Index': 63.94,
#   'Local Purchasing Power Index': 88.66,
#   'split_city': 'Vancouver'},
#  {'City': 'San Juan, Puerto Rico',
#   'COL Index': 72.18,
#   'Rent Index': 24.1,
#   'Groceries Index': 73.71,
#   'Restaurant Price Index': 64.37,
#   'Local Purchasing Power Index': 64.62,
#   'split_city': 'San Juan'},
#  {'City': 'Rotterdam, Netherlands',
#   'COL Index': 72.13,
#   'Rent Index': 37.68,
#   'Groceries Index': 55.5,
#   'Restaurant Price Index': 69.26,
#   'Local Purchasing Power Index': 83.96,
#   'split_city': 'Rotterdam'},
#  {'City': 'Knoxville, TN, United States',
#   'COL Index': 71.85,
#   'Rent Index': 31.64,
#   'Groceries Index': 80.35,
#   'Restaurant Price Index': 59.3,
#   'Local Purchasing Power Index': 98.29,
#   'split_city': 'Knoxville'},
#  {'City': 'Red Deer, Canada',
#   'COL Index': 71.85,
#   'Rent Index': 21.05,
#   'Groceries Index': 66.98,
#   'Restaurant Price Index': 64.31,
#   'Local Purchasing Power Index': 99.95,
#   'split_city': 'Red Deer'},
#  {'City': 'Frankfurt, Germany',
#   'COL Index': 71.84,
#   'Rent Index': 39.17,
#   'Groceries Index': 50.54,
#   'Restaurant Price Index': 65.73,
#   'Local Purchasing Power Index': 99.61,
#   'split_city': 'Frankfurt'},
#  {'City': 'Orlando, FL, United States',
#   'COL Index': 71.81,
#   'Rent Index': 40.24,
#   'Groceries Index': 69.77,
#   'Restaurant Price Index': 72.17,
#   'Local Purchasing Power Index': 103.89,
#   'split_city': 'Orlando'},
#  {'City': 'Nashville, TN, United States',
#   'COL Index': 71.79,
#   'Rent Index': 46.11,
#   'Groceries Index': 64.12,
#   'Restaurant Price Index': 76.91,
#   'Local Purchasing Power Index': 111.67,
#   'split_city': 'Nashville'},
#  {'City': 'Burnaby, Canada',
#   'COL Index': 71.69,
#   'Rent Index': 40.03,
#   'Groceries Index': 72.11,
#   'Restaurant Price Index': 62.72,
#   'Local Purchasing Power Index': 87.57,
#   'split_city': 'Burnaby'},
#  {'City': 'Bologna, Italy',
#   'COL Index': 71.63,
#   'Rent Index': 25.24,
#   'Groceries Index': 64.02,
#   'Restaurant Price Index': 70.69,
#   'Local Purchasing Power Index': 59.6,
#   'split_city': 'Bologna'},
#  {'City': 'Bergamo, Italy',
#   'COL Index': 71.58,
#   'Rent Index': 19.83,
#   'Groceries Index': 62.35,
#   'Restaurant Price Index': 73.25,
#   'Local Purchasing Power Index': 64.19,
#   'split_city': 'Bergamo'},
#  {'City': 'Cambridge, United Kingdom',
#   'COL Index': 71.48,
#   'Rent Index': 38.08,
#   'Groceries Index': 55.72,
#   'Restaurant Price Index': 78.68,
#   'Local Purchasing Power Index': 73.41,
#   'split_city': 'Cambridge'},
#  {'City': 'The Hague (Den Haag), Netherlands',
#   'COL Index': 71.24,
#   'Rent Index': 32.88,
#   'Groceries Index': 56.81,
#   'Restaurant Price Index': 73.27,
#   'Local Purchasing Power Index': 95.5,
#   'split_city': 'The Hague (Den Haag)'},
#  {'City': 'Delft, Netherlands',
#   'COL Index': 71.18,
#   'Rent Index': 28.98,
#   'Groceries Index': 56.91,
#   'Restaurant Price Index': 68.96,
#   'Local Purchasing Power Index': 94.64,
#   'split_city': 'Delft'},
#  {'City': 'Buffalo, NY, United States',
#   'COL Index': 71.18,
#   'Rent Index': 26.79,
#   'Groceries Index': 68.49,
#   'Restaurant Price Index': 63.95,
#   'Local Purchasing Power Index': 102.98,
#   'split_city': 'Buffalo'},
#  {'City': 'Florence, Italy',
#   'COL Index': 71.17,
#   'Rent Index': 29.58,
#   'Groceries Index': 60.67,
#   'Restaurant Price Index': 72.55,
#   'Local Purchasing Power Index': 53.42,
#   'split_city': 'Florence'},
#  {'City': 'Trieste, Italy',
#   'COL Index': 71.16,
#   'Rent Index': 16.79,
#   'Groceries Index': 64.51,
#   'Restaurant Price Index': 69.46,
#   'Local Purchasing Power Index': 66.62,
#   'split_city': 'Trieste'},
#  {'City': 'Olympia, WA, United States',
#   'COL Index': 71.1,
#   'Rent Index': 39.4,
#   'Groceries Index': 68.17,
#   'Restaurant Price Index': 65.97,
#   'Local Purchasing Power Index': 113.63,
#   'split_city': 'Olympia'},
#  {'City': 'Kansas City, MO, United States',
#   'COL Index': 71.04,
#   'Rent Index': 29.21,
#   'Groceries Index': 65.14,
#   'Restaurant Price Index': 69.9,
#   'Local Purchasing Power Index': 117.39,
#   'split_city': 'Kansas City'},
#  {'City': 'Turku, Finland',
#   'COL Index': 70.95,
#   'Rent Index': 21.54,
#   'Groceries Index': 54.65,
#   'Restaurant Price Index': 80.97,
#   'Local Purchasing Power Index': 107.22,
#   'split_city': 'Turku'},
#  {'City': 'Adelaide, Australia',
#   'COL Index': 70.83,
#   'Rent Index': 27.12,
#   'Groceries Index': 69.31,
#   'Restaurant Price Index': 60.56,
#   'Local Purchasing Power Index': 109.59,
#   'split_city': 'Adelaide'},
#  {'City': 'Macao, Macao',
#   'COL Index': 70.81,
#   'Rent Index': 41.26,
#   'Groceries Index': 68.89,
#   'Restaurant Price Index': 49.96,
#   'Local Purchasing Power Index': 72.29,
#   'split_city': 'Macao'},
#  {'City': 'Halifax, Canada',
#   'COL Index': 70.77,
#   'Rent Index': 29.23,
#   'Groceries Index': 75.58,
#   'Restaurant Price Index': 57.41,
#   'Local Purchasing Power Index': 72.8,
#   'split_city': 'Halifax'},
#  {'City': 'Wellington, New Zealand',
#   'COL Index': 70.73,
#   'Rent Index': 37.32,
#   'Groceries Index': 65.29,
#   'Restaurant Price Index': 62.02,
#   'Local Purchasing Power Index': 98.78,
#   'split_city': 'Wellington'},
#  {'City': 'Hobart, Australia',
#   'COL Index': 70.71,
#   'Rent Index': 31.58,
#   'Groceries Index': 66.9,
#   'Restaurant Price Index': 64.6,
#   'Local Purchasing Power Index': 108.44,
#   'split_city': 'Hobart'},
#  {'City': 'Victoria, Canada',
#   'COL Index': 70.68,
#   'Rent Index': 37.44,
#   'Groceries Index': 72.98,
#   'Restaurant Price Index': 63.03,
#   'Local Purchasing Power Index': 78.54,
#   'split_city': 'Victoria'},
#  {'City': 'Jacksonville, FL, United States',
#   'COL Index': 70.6,
#   'Rent Index': 32.43,
#   'Groceries Index': 72.25,
#   'Restaurant Price Index': 71.52,
#   'Local Purchasing Power Index': 116.55,
#   'split_city': 'Jacksonville'},
#  {'City': 'Aberdeen, United Kingdom',
#   'COL Index': 70.55,
#   'Rent Index': 24.5,
#   'Groceries Index': 55.45,
#   'Restaurant Price Index': 74.83,
#   'Local Purchasing Power Index': 103.8,
#   'split_city': 'Aberdeen'},
#  {'City': 'Reading, United Kingdom',
#   'COL Index': 70.5,
#   'Rent Index': 36.5,
#   'Groceries Index': 61.78,
#   'Restaurant Price Index': 64.23,
#   'Local Purchasing Power Index': 99.49,
#   'split_city': 'Reading'},
#  {'City': 'York, United Kingdom',
#   'COL Index': 70.4,
#   'Rent Index': 27.98,
#   'Groceries Index': 57.33,
#   'Restaurant Price Index': 69.45,
#   'Local Purchasing Power Index': 78.24,
#   'split_city': 'York'},
#  {'City': 'Heidelberg, Germany',
#   'COL Index': 70.05,
#   'Rent Index': 28.62,
#   'Groceries Index': 49.39,
#   'Restaurant Price Index': 69.45,
#   'Local Purchasing Power Index': 90.57,
#   'split_city': 'Heidelberg'},
#  {'City': 'Raleigh, NC, United States',
#   'COL Index': 69.92,
#   'Rent Index': 35.88,
#   'Groceries Index': 71.34,
#   'Restaurant Price Index': 67.11,
#   'Local Purchasing Power Index': 131.63,
#   'split_city': 'Raleigh'},
#  {'City': 'Lille, France',
#   'COL Index': 69.87,
#   'Rent Index': 24.28,
#   'Groceries Index': 62.62,
#   'Restaurant Price Index': 63.67,
#   'Local Purchasing Power Index': 76.85,
#   'split_city': 'Lille'},
#  {'City': 'Detroit, MI, United States',
#   'COL Index': 69.76,
#   'Rent Index': 40.07,
#   'Groceries Index': 70.68,
#   'Restaurant Price Index': 58.21,
#   'Local Purchasing Power Index': 78.93,
#   'split_city': 'Detroit'},
#  {'City': 'Hamburg, Germany',
#   'COL Index': 69.71,
#   'Rent Index': 32.86,
#   'Groceries Index': 53.23,
#   'Restaurant Price Index': 61.64,
#   'Local Purchasing Power Index': 89.26,
#   'split_city': 'Hamburg'},
#  {'City': 'Lincoln, United Kingdom',
#   'COL Index': 69.62,
#   'Rent Index': 20.45,
#   'Groceries Index': 53.24,
#   'Restaurant Price Index': 76.61,
#   'Local Purchasing Power Index': 97.72,
#   'split_city': 'Lincoln'},
#  {'City': 'Dresden, Germany',
#   'COL Index': 69.61,
#   'Rent Index': 22.25,
#   'Groceries Index': 51.76,
#   'Restaurant Price Index': 62.8,
#   'Local Purchasing Power Index': 101.86,
#   'split_city': 'Dresden'},
#  {'City': 'Edmonton, Canada',
#   'COL Index': 69.55,
#   'Rent Index': 25.72,
#   'Groceries Index': 64.82,
#   'Restaurant Price Index': 66.28,
#   'Local Purchasing Power Index': 89.24,
#   'split_city': 'Edmonton'},
#  {'City': 'Tucson, AZ, United States',
#   'COL Index': 69.41,
#   'Rent Index': 26.93,
#   'Groceries Index': 63.5,
#   'Restaurant Price Index': 56.74,
#   'Local Purchasing Power Index': 99.39,
#   'split_city': 'Tucson'},
#  {'City': 'Bristol, United Kingdom',
#   'COL Index': 69.37,
#   'Rent Index': 34.31,
#   'Groceries Index': 52.78,
#   'Restaurant Price Index': 76.12,
#   'Local Purchasing Power Index': 83.23,
#   'split_city': 'Bristol'},
#  {'City': 'Nuremberg, Germany',
#   'COL Index': 69.32,
#   'Rent Index': 25.08,
#   'Groceries Index': 56.73,
#   'Restaurant Price Index': 59.0,
#   'Local Purchasing Power Index': 93.46,
#   'split_city': 'Nuremberg'},
#  {'City': 'Calgary, Canada',
#   'COL Index': 69.13,
#   'Rent Index': 27.09,
#   'Groceries Index': 63.75,
#   'Restaurant Price Index': 66.6,
#   'Local Purchasing Power Index': 111.77,
#   'split_city': 'Calgary'},
#  {'City': 'Eugene, OR, United States',
#   'COL Index': 69.13,
#   'Rent Index': 33.17,
#   'Groceries Index': 75.16,
#   'Restaurant Price Index': 56.08,
#   'Local Purchasing Power Index': 95.13,
#   'split_city': 'Eugene'},
#  {'City': 'Espoo, Finland',
#   'COL Index': 69.1,
#   'Rent Index': 27.93,
#   'Groceries Index': 53.03,
#   'Restaurant Price Index': 77.11,
#   'Local Purchasing Power Index': 117.71,
#   'split_city': 'Espoo'},
#  {'City': 'Portsmouth, United Kingdom',
#   'COL Index': 69.05,
#   'Rent Index': 29.87,
#   'Groceries Index': 56.29,
#   'Restaurant Price Index': 82.16,
#   'Local Purchasing Power Index': 88.28,
#   'split_city': 'Portsmouth'},
#  {'City': 'Oxford, United Kingdom',
#   'COL Index': 68.99,
#   'Rent Index': 43.22,
#   'Groceries Index': 55.04,
#   'Restaurant Price Index': 65.1,
#   'Local Purchasing Power Index': 89.2,
#   'split_city': 'Oxford'},
#  {'City': 'Dubai, United Arab Emirates',
#   'COL Index': 68.83,
#   'Rent Index': 49.35,
#   'Groceries Index': 53.87,
#   'Restaurant Price Index': 65.63,
#   'Local Purchasing Power Index': 84.39,
#   'split_city': 'Dubai'},
#  {'City': 'Stuttgart, Germany',
#   'COL Index': 68.78,
#   'Rent Index': 32.29,
#   'Groceries Index': 52.31,
#   'Restaurant Price Index': 68.83,
#   'Local Purchasing Power Index': 100.56,
#   'split_city': 'Stuttgart'},
#  {'City': 'Reno, NV, United States',
#   'COL Index': 68.75,
#   'Rent Index': 37.41,
#   'Groceries Index': 67.2,
#   'Restaurant Price Index': 66.48,
#   'Local Purchasing Power Index': 125.28,
#   'split_city': 'Reno'},
#  {'City': 'Richmond, VA, United States',
#   'COL Index': 68.72,
#   'Rent Index': 33.84,
#   'Groceries Index': 65.91,
#   'Restaurant Price Index': 70.82,
#   'Local Purchasing Power Index': 114.52,
#   'split_city': 'Richmond'},
#  {'City': 'Las Vegas, NV, United States',
#   'COL Index': 68.63,
#   'Rent Index': 35.82,
#   'Groceries Index': 57.65,
#   'Restaurant Price Index': 73.09,
#   'Local Purchasing Power Index': 117.4,
#   'split_city': 'Las Vegas'},
#  {'City': 'Louisville, KY, United States',
#   'COL Index': 68.62,
#   'Rent Index': 30.89,
#   'Groceries Index': 66.34,
#   'Restaurant Price Index': 72.87,
#   'Local Purchasing Power Index': 110.16,
#   'split_city': 'Louisville'},
#  {'City': 'Edinburgh, United Kingdom',
#   'COL Index': 68.54,
#   'Rent Index': 31.94,
#   'Groceries Index': 53.04,
#   'Restaurant Price Index': 79.66,
#   'Local Purchasing Power Index': 80.36,
#   'split_city': 'Edinburgh'},
#  {'City': 'Beirut, Lebanon',
#   'COL Index': 68.48,
#   'Rent Index': 24.37,
#   'Groceries Index': 54.96,
#   'Restaurant Price Index': 60.73,
#   'Local Purchasing Power Index': 30.87,
#   'split_city': 'Beirut'},
#  {'City': 'Turin, Italy',
#   'COL Index': 68.41,
#   'Rent Index': 20.6,
#   'Groceries Index': 55.96,
#   'Restaurant Price Index': 70.39,
#   'Local Purchasing Power Index': 62.31,
#   'split_city': 'Turin'},
#  {'City': 'Houston, TX, United States',
#   'COL Index': 68.38,
#   'Rent Index': 42.25,
#   'Groceries Index': 63.55,
#   'Restaurant Price Index': 71.38,
#   'Local Purchasing Power Index': 130.69,
#   'split_city': 'Houston'},
#  {'City': 'Bonn, Germany',
#   'COL Index': 68.36,
#   'Rent Index': 29.1,
#   'Groceries Index': 50.03,
#   'Restaurant Price Index': 61.04,
#   'Local Purchasing Power Index': 97.25,
#   'split_city': 'Bonn'},
#  {'City': 'Toledo, OH, United States',
#   'COL Index': 68.04,
#   'Rent Index': 20.59,
#   'Groceries Index': 66.75,
#   'Restaurant Price Index': 61.87,
#   'Local Purchasing Power Index': 102.54,
#   'split_city': 'Toledo'},
#  {'City': 'Mannheim, Germany',
#   'COL Index': 67.95,
#   'Rent Index': 20.76,
#   'Groceries Index': 48.38,
#   'Restaurant Price Index': 61.46,
#   'Local Purchasing Power Index': 93.6,
#   'split_city': 'Mannheim'},
#  {'City': 'Coquitlam, Canada',
#   'COL Index': 67.88,
#   'Rent Index': 40.22,
#   'Groceries Index': 70.95,
#   'Restaurant Price Index': 50.3,
#   'Local Purchasing Power Index': 79.6,
#   'split_city': 'Coquitlam'},
#  {'City': 'Vienna, Austria',
#   'COL Index': 67.83,
#   'Rent Index': 30.64,
#   'Groceries Index': 58.3,
#   'Restaurant Price Index': 62.62,
#   'Local Purchasing Power Index': 84.39,
#   'split_city': 'Vienna'},
#  {'City': 'Des Moines, IA, United States',
#   'COL Index': 67.73,
#   'Rent Index': 27.26,
#   'Groceries Index': 69.63,
#   'Restaurant Price Index': 57.03,
#   'Local Purchasing Power Index': 118.9,
#   'split_city': 'Des Moines'},
#  {'City': 'Saskatoon, Canada',
#   'COL Index': 67.68,
#   'Rent Index': 23.44,
#   'Groceries Index': 61.05,
#   'Restaurant Price Index': 63.22,
#   'Local Purchasing Power Index': 88.83,
#   'split_city': 'Saskatoon'},
#  {'City': 'Dusseldorf, Germany',
#   'COL Index': 67.67,
#   'Rent Index': 27.62,
#   'Groceries Index': 49.29,
#   'Restaurant Price Index': 64.02,
#   'Local Purchasing Power Index': 98.08,
#   'split_city': 'Dusseldorf'},
#  {'City': 'San Antonio, TX, United States',
#   'COL Index': 67.58,
#   'Rent Index': 35.11,
#   'Groceries Index': 64.9,
#   'Restaurant Price Index': 63.92,
#   'Local Purchasing Power Index': 109.29,
#   'split_city': 'San Antonio'},
#  {'City': 'Ottawa, Canada',
#   'COL Index': 67.55,
#   'Rent Index': 33.98,
#   'Groceries Index': 61.79,
#   'Restaurant Price Index': 66.8,
#   'Local Purchasing Power Index': 93.62,
#   'split_city': 'Ottawa'},
#  {'City': 'Nottingham, United Kingdom',
#   'COL Index': 67.48,
#   'Rent Index': 21.98,
#   'Groceries Index': 57.34,
#   'Restaurant Price Index': 65.25,
#   'Local Purchasing Power Index': 77.76,
#   'split_city': 'Nottingham'},
#  {'City': 'Cologne, Germany',
#   'COL Index': 67.47,
#   'Rent Index': 28.16,
#   'Groceries Index': 48.16,
#   'Restaurant Price Index': 64.65,
#   'Local Purchasing Power Index': 90.77,
#   'split_city': 'Cologne'},
#  {'City': 'Freiburg im Breisgau, Germany',
#   'COL Index': 67.47,
#   'Rent Index': 32.93,
#   'Groceries Index': 52.01,
#   'Restaurant Price Index': 64.11,
#   'Local Purchasing Power Index': 95.26,
#   'split_city': 'Freiburg im Breisgau'},
#  {'City': 'Mississauga, Canada',
#   'COL Index': 67.43,
#   'Rent Index': 40.41,
#   'Groceries Index': 61.86,
#   'Restaurant Price Index': 58.11,
#   'Local Purchasing Power Index': 97.04,
#   'split_city': 'Mississauga'},
#  {'City': 'Doha, Qatar',
#   'COL Index': 67.37,
#   'Rent Index': 45.63,
#   'Groceries Index': 59.3,
#   'Restaurant Price Index': 64.15,
#   'Local Purchasing Power Index': 95.55,
#   'split_city': 'Doha'},
#  {'City': 'Kelowna, Canada',
#   'COL Index': 67.34,
#   'Rent Index': 31.98,
#   'Groceries Index': 62.72,
#   'Restaurant Price Index': 64.16,
#   'Local Purchasing Power Index': 86.78,
#   'split_city': 'Kelowna'},
#  {'City': 'Phoenix, AZ, United States',
#   'COL Index': 67.11,
#   'Rent Index': 35.86,
#   'Groceries Index': 62.19,
#   'Restaurant Price Index': 63.57,
#   'Local Purchasing Power Index': 120.4,
#   'split_city': 'Phoenix'},
#  {'City': 'Manchester, United Kingdom',
#   'COL Index': 67.11,
#   'Rent Index': 28.61,
#   'Groceries Index': 54.35,
#   'Restaurant Price Index': 73.1,
#   'Local Purchasing Power Index': 94.42,
#   'split_city': 'Manchester'},
#  {'City': 'Birmingham, United Kingdom',
#   'COL Index': 67.07,
#   'Rent Index': 27.79,
#   'Groceries Index': 54.93,
#   'Restaurant Price Index': 65.05,
#   'Local Purchasing Power Index': 81.41,
#   'split_city': 'Birmingham'},
#  {'City': 'Brampton, Canada',
#   'COL Index': 67.04,
#   'Rent Index': 35.36,
#   'Groceries Index': 60.66,
#   'Restaurant Price Index': 56.29,
#   'Local Purchasing Power Index': 79.5,
#   'split_city': 'Brampton'},
#  {'City': 'Berlin, Germany',
#   'COL Index': 67.02,
#   'Rent Index': 32.07,
#   'Groceries Index': 53.26,
#   'Restaurant Price Index': 53.79,
#   'Local Purchasing Power Index': 98.15,
#   'split_city': 'Berlin'},
#  {'City': 'Tulsa, OK, United States',
#   'COL Index': 66.87,
#   'Rent Index': 26.73,
#   'Groceries Index': 67.89,
#   'Restaurant Price Index': 59.5,
#   'Local Purchasing Power Index': 115.7,
#   'split_city': 'Tulsa'},
#  {'City': 'Madison, WI, United States',
#   'COL Index': 66.75,
#   'Rent Index': 36.44,
#   'Groceries Index': 62.25,
#   'Restaurant Price Index': 64.32,
#   'Local Purchasing Power Index': 120.56,
#   'split_city': 'Madison'},
#  {'City': 'Kaohsiung, Taiwan',
#   'COL Index': 66.08,
#   'Rent Index': 10.69,
#   'Groceries Index': 83.8,
#   'Restaurant Price Index': 26.19,
#   'Local Purchasing Power Index': 53.51,
#   'split_city': 'Kaohsiung'},
#  {'City': 'Padova, Italy',
#   'COL Index': 66.06,
#   'Rent Index': 20.33,
#   'Groceries Index': 51.24,
#   'Restaurant Price Index': 65.93,
#   'Local Purchasing Power Index': 64.36,
#   'split_city': 'Padova'},
#  {'City': 'Southampton, United Kingdom',
#   'COL Index': 66.05,
#   'Rent Index': 28.36,
#   'Groceries Index': 52.37,
#   'Restaurant Price Index': 66.8,
#   'Local Purchasing Power Index': 91.07,
#   'split_city': 'Southampton'},
#  {'City': 'Exeter, United Kingdom',
#   'COL Index': 65.93,
#   'Rent Index': 24.55,
#   'Groceries Index': 50.67,
#   'Restaurant Price Index': 66.91,
#   'Local Purchasing Power Index': 90.66,
#   'split_city': 'Exeter'},
#  {'City': 'Regina, Canada',
#   'COL Index': 65.71,
#   'Rent Index': 25.42,
#   'Groceries Index': 65.05,
#   'Restaurant Price Index': 57.99,
#   'Local Purchasing Power Index': 86.49,
#   'split_city': 'Regina'},
#  {'City': 'Plymouth, United Kingdom',
#   'COL Index': 65.68,
#   'Rent Index': 21.69,
#   'Groceries Index': 49.63,
#   'Restaurant Price Index': 69.78,
#   'Local Purchasing Power Index': 81.89,
#   'split_city': 'Plymouth'},
#  {'City': 'Dundee, United Kingdom',
#   'COL Index': 65.62,
#   'Rent Index': 20.63,
#   'Groceries Index': 54.05,
#   'Restaurant Price Index': 72.63,
#   'Local Purchasing Power Index': 87.0,
#   'split_city': 'Dundee'},
#  {'City': 'Nicosia, Cyprus',
#   'COL Index': 65.52,
#   'Rent Index': 18.76,
#   'Groceries Index': 55.97,
#   'Restaurant Price Index': 64.43,
#   'Local Purchasing Power Index': 55.63,
#   'split_city': 'Nicosia'},
#  {'City': 'Salt Lake City, UT, United States',
#   'COL Index': 65.47,
#   'Rent Index': 35.94,
#   'Groceries Index': 60.93,
#   'Restaurant Price Index': 62.29,
#   'Local Purchasing Power Index': 125.21,
#   'split_city': 'Salt Lake City'},
#  {'City': 'Dallas, TX, United States',
#   'COL Index': 65.27,
#   'Rent Index': 47.46,
#   'Groceries Index': 57.42,
#   'Restaurant Price Index': 65.48,
#   'Local Purchasing Power Index': 147.47,
#   'split_city': 'Dallas'},
#  {'City': 'Stoke-on-Trent, United Kingdom',
#   'COL Index': 65.1,
#   'Rent Index': 14.51,
#   'Groceries Index': 48.7,
#   'Restaurant Price Index': 68.4,
#   'Local Purchasing Power Index': 88.11,
#   'split_city': 'Stoke-on-Trent'},
#  {'City': 'Indianapolis, IN, United States',
#   'COL Index': 65.02,
#   'Rent Index': 29.01,
#   'Groceries Index': 61.6,
#   'Restaurant Price Index': 55.62,
#   'Local Purchasing Power Index': 116.36,
#   'split_city': 'Indianapolis'},
#  {'City': 'Hamilton, Canada',
#   'COL Index': 65.02,
#   'Rent Index': 26.93,
#   'Groceries Index': 62.6,
#   'Restaurant Price Index': 56.89,
#   'Local Purchasing Power Index': 90.86,
#   'split_city': 'Hamilton'},
#  {'City': 'Coventry, United Kingdom',
#   'COL Index': 65.0,
#   'Rent Index': 26.31,
#   'Groceries Index': 54.97,
#   'Restaurant Price Index': 60.67,
#   'Local Purchasing Power Index': 103.42,
#   'split_city': 'Coventry'},
#  {'City': 'Essen, Germany',
#   'COL Index': 64.94,
#   'Rent Index': 19.91,
#   'Groceries Index': 47.96,
#   'Restaurant Price Index': 64.28,
#   'Local Purchasing Power Index': 85.53,
#   'split_city': 'Essen'},
#  {'City': 'Bilbao, Spain',
#   'COL Index': 64.85,
#   'Rent Index': 26.11,
#   'Groceries Index': 55.47,
#   'Restaurant Price Index': 60.44,
#   'Local Purchasing Power Index': 68.06,
#   'split_city': 'Bilbao'},
#  {'City': 'Naples, Italy',
#   'COL Index': 64.75,
#   'Rent Index': 20.35,
#   'Groceries Index': 55.42,
#   'Restaurant Price Index': 54.64,
#   'Local Purchasing Power Index': 50.25,
#   'split_city': 'Naples'},
#  {'City': 'Cardiff, United Kingdom',
#   'COL Index': 64.68,
#   'Rent Index': 24.35,
#   'Groceries Index': 55.17,
#   'Restaurant Price Index': 58.71,
#   'Local Purchasing Power Index': 90.45,
#   'split_city': 'Cardiff'},
#  {'City': 'Bremen, Germany',
#   'COL Index': 64.54,
#   'Rent Index': 22.68,
#   'Groceries Index': 49.21,
#   'Restaurant Price Index': 58.8,
#   'Local Purchasing Power Index': 83.76,
#   'split_city': 'Bremen'},
#  {'City': 'Little Rock, AR, United States',
#   'COL Index': 64.51,
#   'Rent Index': 25.94,
#   'Groceries Index': 60.22,
#   'Restaurant Price Index': 67.63,
#   'Local Purchasing Power Index': 126.77,
#   'split_city': 'Little Rock'},
#  {'City': 'Liverpool, United Kingdom',
#   'COL Index': 64.46,
#   'Rent Index': 22.61,
#   'Groceries Index': 49.55,
#   'Restaurant Price Index': 71.74,
#   'Local Purchasing Power Index': 85.27,
#   'split_city': 'Liverpool'},
#  {'City': 'Austin, TX, United States',
#   'COL Index': 64.45,
#   'Rent Index': 48.76,
#   'Groceries Index': 63.58,
#   'Restaurant Price Index': 61.76,
#   'Local Purchasing Power Index': 131.76,
#   'split_city': 'Austin'},
#  {'City': 'Derby, United Kingdom',
#   'COL Index': 64.37,
#   'Rent Index': 19.26,
#   'Groceries Index': 50.85,
#   'Restaurant Price Index': 66.61,
#   'Local Purchasing Power Index': 89.85,
#   'split_city': 'Derby'},
#  {'City': 'Taipei, Taiwan',
#   'COL Index': 64.12,
#   'Rent Index': 20.72,
#   'Groceries Index': 76.35,
#   'Restaurant Price Index': 29.27,
#   'Local Purchasing Power Index': 63.96,
#   'split_city': 'Taipei'},
#  {'City': 'Montreal, Canada',
#   'COL Index': 64.1,
#   'Rent Index': 26.75,
#   'Groceries Index': 66.01,
#   'Restaurant Price Index': 56.21,
#   'Local Purchasing Power Index': 89.61,
#   'split_city': 'Montreal'},
#  {'City': 'Cincinnati, OH, United States',
#   'COL Index': 64.04,
#   'Rent Index': 34.26,
#   'Groceries Index': 61.75,
#   'Restaurant Price Index': 57.99,
#   'Local Purchasing Power Index': 122.1,
#   'split_city': 'Cincinnati'},
#  {'City': 'Kitchener, Canada',
#   'COL Index': 64.04,
#   'Rent Index': 27.87,
#   'Groceries Index': 58.3,
#   'Restaurant Price Index': 60.82,
#   'Local Purchasing Power Index': 86.17,
#   'split_city': 'Kitchener'},
#  {'City': 'Winnipeg, Canada',
#   'COL Index': 63.66,
#   'Rent Index': 22.95,
#   'Groceries Index': 60.99,
#   'Restaurant Price Index': 56.39,
#   'Local Purchasing Power Index': 89.02,
#   'split_city': 'Winnipeg'},
#  {'City': 'Limassol, Cyprus',
#   'COL Index': 63.62,
#   'Rent Index': 28.65,
#   'Groceries Index': 49.55,
#   'Restaurant Price Index': 67.89,
#   'Local Purchasing Power Index': 58.52,
#   'split_city': 'Limassol'},
#  {'City': 'Albuquerque, NM, United States',
#   'COL Index': 63.61,
#   'Rent Index': 26.04,
#   'Groceries Index': 60.94,
#   'Restaurant Price Index': 65.42,
#   'Local Purchasing Power Index': 112.61,
#   'split_city': 'Albuquerque'},
#  {'City': 'Leicester, United Kingdom',
#   'COL Index': 63.37,
#   'Rent Index': 21.32,
#   'Groceries Index': 48.09,
#   'Restaurant Price Index': 63.67,
#   'Local Purchasing Power Index': 89.68,
#   'split_city': 'Leicester'},
#  {'City': 'Glasgow, United Kingdom',
#   'COL Index': 63.34,
#   'Rent Index': 23.09,
#   'Groceries Index': 50.59,
#   'Restaurant Price Index': 67.84,
#   'Local Purchasing Power Index': 95.15,
#   'split_city': 'Glasgow'},
#  {'City': 'Newcastle upon Tyne, United Kingdom',
#   'COL Index': 63.21,
#   'Rent Index': 22.86,
#   'Groceries Index': 51.81,
#   'Restaurant Price Index': 62.58,
#   'Local Purchasing Power Index': 85.19,
#   'split_city': 'Newcastle upon Tyne'},
#  {'City': 'Hanover, Germany',
#   'COL Index': 63.18,
#   'Rent Index': 25.38,
#   'Groceries Index': 47.92,
#   'Restaurant Price Index': 60.27,
#   'Local Purchasing Power Index': 103.95,
# ...
#   'Local Purchasing Power Index': 23.48,
#   'split_city': 'Mykolaiv'},
#  {'City': 'Recife, Brazil',
#   'COL Index': 31.42,
#   'Rent Index': 7.44,
#   'Groceries Index': 23.24,
#   'Restaurant Price Index': 22.01,
#   'Local Purchasing Power Index': 21.52,
#   'split_city': 'Recife'},
#  {'City': 'Odessa (Odesa), Ukraine',
#   'COL Index': 31.4,
#   'Rent Index': 9.9,
#   'Groceries Index': 25.05,
#   'Restaurant Price Index': 24.68,
#   'Local Purchasing Power Index': 33.41,
#   'split_city': 'Odessa (Odesa)'},
#  {'City': 'Asuncion, Paraguay',
#   'COL Index': 31.36,
#   'Rent Index': 9.77,
#   'Groceries Index': 25.75,
#   'Restaurant Price Index': 25.75,
#   'Local Purchasing Power Index': 31.55,
#   'split_city': 'Asuncion'},
#  {'City': 'Perm, Russia',
#   'COL Index': 31.28,
#   'Rent Index': 7.51,
#   'Groceries Index': 25.73,
#   'Restaurant Price Index': 26.89,
#   'Local Purchasing Power Index': 38.53,
#   'split_city': 'Perm'},
#  {'City': 'Damascus, Syria',
#   'COL Index': 31.17,
#   'Rent Index': 8.6,
#   'Groceries Index': 28.21,
#   'Restaurant Price Index': 28.21,
#   'Local Purchasing Power Index': 8.59,
#   'split_city': 'Damascus'},
#  {'City': 'Algiers, Algeria',
#   'COL Index': 31.14,
#   'Rent Index': 7.43,
#   'Groceries Index': 30.47,
#   'Restaurant Price Index': 17.68,
#   'Local Purchasing Power Index': 26.88,
#   'split_city': 'Algiers'},
#  {'City': 'Belo Horizonte, Brazil',
#   'COL Index': 31.1,
#   'Rent Index': 7.38,
#   'Groceries Index': 22.97,
#   'Restaurant Price Index': 22.56,
#   'Local Purchasing Power Index': 24.06,
#   'split_city': 'Belo Horizonte'},
#  {'City': 'Guadalajara, Mexico',
#   'COL Index': 31.07,
#   'Rent Index': 10.76,
#   'Groceries Index': 29.47,
#   'Restaurant Price Index': 25.82,
#   'Local Purchasing Power Index': 39.36,
#   'split_city': 'Guadalajara'},
#  {'City': 'Almaty, Kazakhstan',
#   'COL Index': 31.07,
#   'Rent Index': 10.54,
#   'Groceries Index': 27.2,
#   'Restaurant Price Index': 26.42,
#   'Local Purchasing Power Index': 36.32,
#   'split_city': 'Almaty'},
#  {'City': 'Volgograd, Russia',
#   'COL Index': 31.03,
#   'Rent Index': 7.13,
#   'Groceries Index': 23.39,
#   'Restaurant Price Index': 35.57,
#   'Local Purchasing Power Index': 32.33,
#   'split_city': 'Volgograd'},
#  {'City': 'Krasnodar, Russia',
#   'COL Index': 31.01,
#   'Rent Index': 8.24,
#   'Groceries Index': 24.99,
#   'Restaurant Price Index': 27.69,
#   'Local Purchasing Power Index': 38.26,
#   'split_city': 'Krasnodar'},
#  {'City': 'Bogota, Colombia',
#   'COL Index': 30.99,
#   'Rent Index': 11.95,
#   'Groceries Index': 25.23,
#   'Restaurant Price Index': 22.26,
#   'Local Purchasing Power Index': 25.19,
#   'split_city': 'Bogota'},
#  {'City': 'Tomsk, Russia',
#   'COL Index': 30.81,
#   'Rent Index': 6.92,
#   'Groceries Index': 26.42,
#   'Restaurant Price Index': 24.58,
#   'Local Purchasing Power Index': 38.13,
#   'split_city': 'Tomsk'},
#  {'City': 'Saratov, Russia',
#   'COL Index': 30.8,
#   'Rent Index': 6.61,
#   'Groceries Index': 24.61,
#   'Restaurant Price Index': 29.33,
#   'Local Purchasing Power Index': 29.11,
#   'split_city': 'Saratov'},
#  {'City': 'Chelyabinsk, Russia',
#   'COL Index': 30.64,
#   'Rent Index': 6.33,
#   'Groceries Index': 25.14,
#   'Restaurant Price Index': 24.33,
#   'Local Purchasing Power Index': 38.35,
#   'split_city': 'Chelyabinsk'},
#  {'City': 'Puebla, Mexico',
#   'COL Index': 30.59,
#   'Rent Index': 7.88,
#   'Groceries Index': 29.72,
#   'Restaurant Price Index': 20.87,
#   'Local Purchasing Power Index': 36.32,
#   'split_city': 'Puebla'},
#  {'City': 'Porto Alegre, Brazil',
#   'COL Index': 30.54,
#   'Rent Index': 7.82,
#   'Groceries Index': 23.7,
#   'Restaurant Price Index': 22.41,
#   'Local Purchasing Power Index': 31.76,
#   'split_city': 'Porto Alegre'},
#  {'City': 'Chittagong, Bangladesh',
#   'COL Index': 30.52,
#   'Rent Index': 4.08,
#   'Groceries Index': 28.1,
#   'Restaurant Price Index': 19.31,
#   'Local Purchasing Power Index': 28.93,
#   'split_city': 'Chittagong'},
#  {'City': 'Kharkiv, Ukraine',
#   'COL Index': 30.44,
#   'Rent Index': 10.6,
#   'Groceries Index': 23.32,
#   'Restaurant Price Index': 22.72,
#   'Local Purchasing Power Index': 30.89,
#   'split_city': 'Kharkiv'},
#  {'City': 'Kathmandu, Nepal',
#   'COL Index': 30.28,
#   'Rent Index': 5.45,
#   'Groceries Index': 27.67,
#   'Restaurant Price Index': 21.47,
#   'Local Purchasing Power Index': 19.08,
#   'split_city': 'Kathmandu'},
#  {'City': 'Barranquilla, Colombia',
#   'COL Index': 30.26,
#   'Rent Index': 7.94,
#   'Groceries Index': 25.8,
#   'Restaurant Price Index': 20.27,
#   'Local Purchasing Power Index': 29.56,
#   'split_city': 'Barranquilla'},
#  {'City': 'Antalya, Turkey',
#   'COL Index': 30.26,
#   'Rent Index': 5.1,
#   'Groceries Index': 26.92,
#   'Restaurant Price Index': 20.26,
#   'Local Purchasing Power Index': 39.82,
#   'split_city': 'Antalya'},
#  {'City': 'Tbilisi, Georgia',
#   'COL Index': 30.25,
#   'Rent Index': 11.53,
#   'Groceries Index': 24.95,
#   'Restaurant Price Index': 27.88,
#   'Local Purchasing Power Index': 25.73,
#   'split_city': 'Tbilisi'},
#  {'City': 'Lviv, Ukraine',
#   'COL Index': 30.13,
#   'Rent Index': 10.31,
#   'Groceries Index': 25.95,
#   'Restaurant Price Index': 23.04,
#   'Local Purchasing Power Index': 29.79,
#   'split_city': 'Lviv'},
#  {'City': 'Dnipro, Ukraine',
#   'COL Index': 30.1,
#   'Rent Index': 8.44,
#   'Groceries Index': 23.56,
#   'Restaurant Price Index': 24.29,
#   'Local Purchasing Power Index': 33.23,
#   'split_city': 'Dnipro'},
#  {'City': 'Tunis, Tunisia',
#   'COL Index': 30.06,
#   'Rent Index': 6.66,
#   'Groceries Index': 28.46,
#   'Restaurant Price Index': 16.49,
#   'Local Purchasing Power Index': 29.69,
#   'split_city': 'Tunis'},
#  {'City': 'Curitiba, Brazil',
#   'COL Index': 30.04,
#   'Rent Index': 6.78,
#   'Groceries Index': 23.11,
#   'Restaurant Price Index': 23.0,
#   'Local Purchasing Power Index': 31.83,
#   'split_city': 'Curitiba'},
#  {'City': 'Gurgaon, India',
#   'COL Index': 29.92,
#   'Rent Index': 8.93,
#   'Groceries Index': 28.42,
#   'Restaurant Price Index': 22.98,
#   'Local Purchasing Power Index': 80.88,
#   'split_city': 'Gurgaon'},
#  {'City': 'Izhevsk, Russia',
#   'COL Index': 29.36,
#   'Rent Index': 6.14,
#   'Groceries Index': 26.07,
#   'Restaurant Price Index': 24.38,
#   'Local Purchasing Power Index': 35.74,
#   'split_city': 'Izhevsk'},
#  {'City': 'Chandigarh, India',
#   'COL Index': 29.33,
#   'Rent Index': 5.7,
#   'Groceries Index': 31.91,
#   'Restaurant Price Index': 17.92,
#   'Local Purchasing Power Index': 45.4,
#   'split_city': 'Chandigarh'},
#  {'City': 'Medellin, Colombia',
#   'COL Index': 29.08,
#   'Rent Index': 9.43,
#   'Groceries Index': 25.94,
#   'Restaurant Price Index': 21.24,
#   'Local Purchasing Power Index': 27.69,
#   'split_city': 'Medellin'},
#  {'City': 'Zaporizhzhya, Ukraine',
#   'COL Index': 29.07,
#   'Rent Index': 4.16,
#   'Groceries Index': 24.43,
#   'Restaurant Price Index': 18.95,
#   'Local Purchasing Power Index': 24.65,
#   'split_city': 'Zaporizhzhya'},
#  {'City': 'Vinnytsia, Ukraine',
#   'COL Index': 28.96,
#   'Rent Index': 6.83,
#   'Groceries Index': 24.79,
#   'Restaurant Price Index': 21.34,
#   'Local Purchasing Power Index': 31.08,
#   'split_city': 'Vinnytsia'},
#  {'City': 'Salvador, Brazil',
#   'COL Index': 28.87,
#   'Rent Index': 6.7,
#   'Groceries Index': 21.13,
#   'Restaurant Price Index': 19.99,
#   'Local Purchasing Power Index': 24.6,
#   'split_city': 'Salvador'},
#  {'City': 'Mumbai, India',
#   'COL Index': 28.87,
#   'Rent Index': 19.56,
#   'Groceries Index': 28.63,
#   'Restaurant Price Index': 24.87,
#   'Local Purchasing Power Index': 41.62,
#   'split_city': 'Mumbai'},
#  {'City': 'Alexandria, Egypt',
#   'COL Index': 28.6,
#   'Rent Index': 5.18,
#   'Groceries Index': 26.57,
#   'Restaurant Price Index': 20.51,
#   'Local Purchasing Power Index': 18.43,
#   'split_city': 'Alexandria'},
#  {'City': 'Tashkent, Uzbekistan',
#   'COL Index': 28.3,
#   'Rent Index': 8.06,
#   'Groceries Index': 24.52,
#   'Restaurant Price Index': 21.23,
#   'Local Purchasing Power Index': 22.8,
#   'split_city': 'Tashkent'},
#  {'City': 'Pristina, Kosovo (Disputed Territory)',
#   'COL Index': 28.2,
#   'Rent Index': 8.76,
#   'Groceries Index': 26.55,
#   'Restaurant Price Index': 19.91,
#   'Local Purchasing Power Index': 49.22,
#   'split_city': 'Pristina'},
#  {'City': 'Ternopil, Ukraine',
#   'COL Index': 28.11,
#   'Rent Index': 5.13,
#   'Groceries Index': 24.45,
#   'Restaurant Price Index': 17.56,
#   'Local Purchasing Power Index': 23.24,
#   'split_city': 'Ternopil'},
#  {'City': 'Delhi, India',
#   'COL Index': 27.43,
#   'Rent Index': 8.25,
#   'Groceries Index': 25.54,
#   'Restaurant Price Index': 23.37,
#   'Local Purchasing Power Index': 51.26,
#   'split_city': 'Delhi'},
#  {'City': 'Sumy, Ukraine',
#   'COL Index': 27.38,
#   'Rent Index': 4.55,
#   'Groceries Index': 23.74,
#   'Restaurant Price Index': 17.2,
#   'Local Purchasing Power Index': 24.38,
#   'split_city': 'Sumy'},
#  {'City': 'Cali, Colombia',
#   'COL Index': 27.26,
#   'Rent Index': 6.4,
#   'Groceries Index': 22.65,
#   'Restaurant Price Index': 19.07,
#   'Local Purchasing Power Index': 34.09,
#   'split_city': 'Cali'},
#  {'City': 'Bangalore, India',
#   'COL Index': 26.98,
#   'Rent Index': 8.39,
#   'Groceries Index': 27.68,
#   'Restaurant Price Index': 19.37,
#   'Local Purchasing Power Index': 65.53,
#   'split_city': 'Bangalore'},
#  {'City': 'Goa, India',
#   'COL Index': 26.8,
#   'Rent Index': 6.06,
#   'Groceries Index': 25.73,
#   'Restaurant Price Index': 23.82,
#   'Local Purchasing Power Index': 41.87,
#   'split_city': 'Goa'},
#  {'City': 'Noida, India',
#   'COL Index': 26.64,
#   'Rent Index': 5.37,
#   'Groceries Index': 24.54,
#   'Restaurant Price Index': 20.14,
#   'Local Purchasing Power Index': 60.0,
#   'split_city': 'Noida'},
#  {'City': 'Ahmedabad, India',
#   'COL Index': 26.11,
#   'Rent Index': 6.74,
#   'Groceries Index': 27.29,
#   'Restaurant Price Index': 17.03,
#   'Local Purchasing Power Index': 35.01,
#   'split_city': 'Ahmedabad'},
#  {'City': 'Ghaziabad, India',
#   'COL Index': 26.06,
#   'Rent Index': 4.55,
#   'Groceries Index': 26.44,
#   'Restaurant Price Index': 18.51,
#   'Local Purchasing Power Index': 63.02,
#   'split_city': 'Ghaziabad'},
#  {'City': 'Thane, India',
#   'COL Index': 26.02,
#   'Rent Index': 8.05,
#   'Groceries Index': 24.35,
#   'Restaurant Price Index': 22.31,
#   'Local Purchasing Power Index': 50.25,
#   'split_city': 'Thane'},
#  {'City': 'Pune, India',
#   'COL Index': 25.9,
#   'Rent Index': 6.95,
#   'Groceries Index': 26.56,
#   'Restaurant Price Index': 19.94,
#   'Local Purchasing Power Index': 57.21,
#   'split_city': 'Pune'},
#  {'City': 'Hyderabad, India',
#   'COL Index': 25.69,
#   'Rent Index': 6.35,
#   'Groceries Index': 27.1,
#   'Restaurant Price Index': 16.94,
#   'Local Purchasing Power Index': 55.38,
#   'split_city': 'Hyderabad'},
#  {'City': 'Kolkata, India',
#   'COL Index': 25.26,
#   'Rent Index': 5.51,
#   'Groceries Index': 26.74,
#   'Restaurant Price Index': 18.72,
#   'Local Purchasing Power Index': 41.43,
#   'split_city': 'Kolkata'},
#  {'City': 'Guwahati, India',
#   'COL Index': 25.17,
#   'Rent Index': 3.75,
#   'Groceries Index': 28.16,
#   'Restaurant Price Index': 15.59,
#   'Local Purchasing Power Index': 43.88,
#   'split_city': 'Guwahati'},
#  {'City': 'Navi Mumbai, India',
#   'COL Index': 25.16,
#   'Rent Index': 9.08,
#   'Groceries Index': 26.09,
#   'Restaurant Price Index': 19.26,
#   'Local Purchasing Power Index': 90.61,
#   'split_city': 'Navi Mumbai'},
#  {'City': 'Bishkek, Kyrgyzstan',
#   'COL Index': 25.12,
#   'Rent Index': 7.78,
#   'Groceries Index': 22.61,
#   'Restaurant Price Index': 20.99,
#   'Local Purchasing Power Index': 23.25,
#   'split_city': 'Bishkek'},
#  {'City': 'Chennai, India',
#   'COL Index': 24.74,
#   'Rent Index': 6.05,
#   'Groceries Index': 25.96,
#   'Restaurant Price Index': 16.83,
#   'Local Purchasing Power Index': 49.95,
#   'split_city': 'Chennai'},
#  {'City': 'Indore, India',
#   'COL Index': 24.5,
#   'Rent Index': 3.8,
#   'Groceries Index': 25.47,
#   'Restaurant Price Index': 15.37,
#   'Local Purchasing Power Index': 38.31,
#   'split_city': 'Indore'},
#  {'City': 'Jaipur, India',
#   'COL Index': 24.36,
#   'Rent Index': 4.73,
#   'Groceries Index': 23.88,
#   'Restaurant Price Index': 15.02,
#   'Local Purchasing Power Index': 50.93,
#   'split_city': 'Jaipur'},
#  {'City': 'Ernakulam, India',
#   'COL Index': 24.25,
#   'Rent Index': 5.17,
#   'Groceries Index': 25.91,
#   'Restaurant Price Index': 16.93,
#   'Local Purchasing Power Index': 43.26,
#   'split_city': 'Ernakulam'},
#  {'City': 'Vadodara, India',
#   'COL Index': 23.62,
#   'Rent Index': 3.88,
#   'Groceries Index': 25.02,
#   'Restaurant Price Index': 16.13,
#   'Local Purchasing Power Index': 52.17,
#   'split_city': 'Vadodara'},
#  {'City': 'Surat, India',
#   'COL Index': 23.6,
#   'Rent Index': 3.57,
#   'Groceries Index': 24.48,
#   'Restaurant Price Index': 16.06,
#   'Local Purchasing Power Index': 44.32,
#   'split_city': 'Surat'},
#  {'City': 'Mangalore, India',
#   'COL Index': 23.57,
#   'Rent Index': 4.2,
#   'Groceries Index': 25.8,
#   'Restaurant Price Index': 14.85,
#   'Local Purchasing Power Index': 48.76,
#   'split_city': 'Mangalore'},
#  {'City': 'Rajkot, India',
#   'COL Index': 23.52,
#   'Rent Index': 3.92,
#   'Groceries Index': 23.33,
#   'Restaurant Price Index': 16.58,
#   'Local Purchasing Power Index': 50.02,
#   'split_city': 'Rajkot'},
#  {'City': 'Coimbatore, India',
#   'COL Index': 23.49,
#   'Rent Index': 4.76,
#   'Groceries Index': 26.28,
#   'Restaurant Price Index': 13.62,
#   'Local Purchasing Power Index': 40.39,
#   'split_city': 'Coimbatore'},
#  {'City': 'Madurai, India',
#   'COL Index': 23.42,
#   'Rent Index': 3.26,
#   'Groceries Index': 25.95,
#   'Restaurant Price Index': 11.87,
#   'Local Purchasing Power Index': 37.97,
#   'split_city': 'Madurai'},
#  {'City': 'Patna, India',
#   'COL Index': 23.33,
#   'Rent Index': 3.64,
#   'Groceries Index': 22.62,
#   'Restaurant Price Index': 16.81,
#   'Local Purchasing Power Index': 46.18,
#   'split_city': 'Patna'},
#  {'City': 'Kochi, India',
#   'COL Index': 23.33,
#   'Rent Index': 4.28,
#   'Groceries Index': 26.15,
#   'Restaurant Price Index': 13.58,
#   'Local Purchasing Power Index': 43.12,
#   'split_city': 'Kochi'},
#  {'City': 'Bhopal, India',
#   'COL Index': 23.09,
#   'Rent Index': 3.66,
#   'Groceries Index': 22.78,
#   'Restaurant Price Index': 16.89,
#   'Local Purchasing Power Index': 44.89,
#   'split_city': 'Bhopal'},
#  {'City': 'Nagpur, India',
#   'COL Index': 22.91,
#   'Rent Index': 3.94,
#   'Groceries Index': 22.33,
#   'Restaurant Price Index': 18.0,
#   'Local Purchasing Power Index': 59.67,
#   'split_city': 'Nagpur'},
#  {'City': 'Lucknow (Lakhnau), India',
#   'COL Index': 22.48,
#   'Rent Index': 4.7,
#   'Groceries Index': 20.97,
#   'Restaurant Price Index': 16.48,
#   'Local Purchasing Power Index': 48.4,
#   'split_city': 'Lucknow (Lakhnau)'},
#  {'City': 'Islamabad, Pakistan',
#   'COL Index': 22.46,
#   'Rent Index': 6.07,
#   'Groceries Index': 20.02,
#   'Restaurant Price Index': 17.26,
#   'Local Purchasing Power Index': 28.92,
#   'split_city': 'Islamabad'},
#  {'City': 'Mysore, India',
#   'COL Index': 22.45,
#   'Rent Index': 4.23,
#   'Groceries Index': 23.57,
#   'Restaurant Price Index': 13.14,
#   'Local Purchasing Power Index': 50.68,
#   'split_city': 'Mysore'},
#  {'City': 'Vijayawada, India',
#   'COL Index': 22.23,
#   'Rent Index': 4.87,
#   'Groceries Index': 24.04,
#   'Restaurant Price Index': 12.37,
#   'Local Purchasing Power Index': 39.16,
#   'split_city': 'Vijayawada'},
#  {'City': 'Bhubaneswar, India',
#   'COL Index': 22.11,
#   'Rent Index': 3.66,
#   'Groceries Index': 23.78,
#   'Restaurant Price Index': 11.86,
#   'Local Purchasing Power Index': 59.2,
#   'split_city': 'Bhubaneswar'},
#  {'City': 'Lahore, Pakistan',
#   'COL Index': 21.96,
#   'Rent Index': 4.5,
#   'Groceries Index': 18.91,
#   'Restaurant Price Index': 16.02,
#   'Local Purchasing Power Index': 27.48,
#   'split_city': 'Lahore'},
#  {'City': 'Karachi, Pakistan',
#   'COL Index': 21.52,
#   'Rent Index': 4.21,
#   'Groceries Index': 18.85,
#   'Restaurant Price Index': 16.73,
#   'Local Purchasing Power Index': 27.94,
#   'split_city': 'Karachi'},
#  {'City': 'Visakhapatnam, India',
#   'COL Index': 21.3,
#   'Rent Index': 3.8,
#   'Groceries Index': 22.62,
#   'Restaurant Price Index': 13.06,
#   'Local Purchasing Power Index': 49.37,
#   'split_city': 'Visakhapatnam'},
#  {'City': 'Thiruvananthapuram, India',
#   'COL Index': 19.85,
#   'Rent Index': 4.17,
#   'Groceries Index': 21.09,
#   'Restaurant Price Index': 10.74,
#   'Local Purchasing Power Index': 59.95,
#   'split_city': 'Thiruvananthapuram'}]
